# %%
# !pip3 install nltk==3.2.4
# Out:
# Collecting nltk==3.2.4
#   Downloading https://files.pythonhosted.org/packages/cd/c2/858e0708b497116ae45cf5c6b1f66984ac60729c61e49df6c1c0b808d1e4/nltk-3.2.4.tar.gz (1.2MB)
#      |████████████████████████████████| 1.2MB 2.8MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk==3.2.4) (1.12.0)
# Building wheels for collected packages: nltk
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.2.4-cp36-none-any.whl size=1367705 sha256=bfe0eecc0069a84c1f5cdf84241551fd25ab46c542f7d2270f8f4503551f710b
#   Stored in directory: /root/.cache/pip/wheels/36/f1/5c/f667347d86a3a534ba4c0127eed4389f929916e3ec88bb461a
# Successfully built nltk
# Installing collected packages: nltk
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# Successfully installed nltk-3.2.4

# %%
# !pip3 install torchtext==0.2.0
# Out:
# Collecting torchtext==0.2.0
#   Downloading https://files.pythonhosted.org/packages/3c/73/ac7461744aad1685595e112958555e1c8bc460e01d11047467b23521eb43/torchtext-0.2.0-py3-none-any.whl (40kB)
#      |████████████████████████████████| 40kB 2.3MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torchtext==0.2.0) (4.28.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext==0.2.0) (2.21.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.0) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.0) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.0) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.0) (1.24.3)
# Installing collected packages: torchtext
#   Found existing installation: torchtext 0.3.1
#     Uninstalling torchtext-0.3.1:
#       Successfully uninstalled torchtext-0.3.1
# Successfully installed torchtext-0.2.0

# %%
# !pip3 install torch==0.3.1
# Out:
# Collecting torch==0.3.1
#   Downloading https://files.pythonhosted.org/packages/5b/a5/e8b50b55b1abac9f1e3346c4242f1e42a82d368a8442cbd50c532922f6c4/torch-0.3.1-cp36-cp36m-manylinux1_x86_64.whl (496.4MB)
#      |████████████████████████████████| 496.4MB 30kB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==0.3.1) (1.17.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from torch==0.3.1) (3.13)
# ERROR: torchvision 0.4.2 has requirement torch==1.3.1, but you'll have torch 0.3.1 which is incompatible.
# ERROR: fastai 1.0.59 has requirement torch>=1.0.0, but you'll have torch 0.3.1 which is incompatible.
# Installing collected packages: torch
#   Found existing installation: torch 1.3.1
#     Uninstalling torch-1.3.1:
#       Successfully uninstalled torch-1.3.1
# Successfully installed torch-0.3.1

# %%
# !pip3 install tensorboardX==0.8[
# Out:
# Collecting tensorboardX==0.8
#   Downloading https://files.pythonhosted.org/packages/15/ef/bc8ca04d56332d277b902b8d74a68759419f6e1e0dfef61630afab1785e9/tensorboardX-0.8-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX==0.8) (1.12.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from tensorboardX==0.8) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX==0.8) (1.17.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->tensorboardX==0.8) (42.0.1)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-0.8

# %%
import argparse

import torch
from torch import nn
from torch.autograd import Variable



def test(model, args, data, mode='test'):
    if mode == 'dev':
        iterator = iter(data.dev_iter)
    else:
        iterator = iter(data.test_iter)

    criterion = nn.CrossEntropyLoss()
    model.eval()
    acc, loss, size = 0, 0, 0

    for batch in iterator:
        if args["data_type"] == 'SNLI':
            s1, s2 = 'premise', 'hypothesis'
        else:
            s1, s2 = 'q1', 'q2'

        s1, s2 = getattr(batch, s1), getattr(batch, s2)
        kwargs = {'p': s1, 'h': s2}

        if args["use_char_emb"]:
            char_p = Variable(torch.LongTensor(data.characterize(s1)))
            char_h = Variable(torch.LongTensor(data.characterize(s2)))

            if args["gpu"] > -1:
                char_p = char_p.cuda(args["gpu"])
                char_h = char_h.cuda(args["gpu"])

            kwargs['char_p'] = char_p
            kwargs['char_h'] = char_h

        pred = model(**kwargs)

        batch_loss = criterion(pred, batch.label)
        loss += batch_loss.data[0]

        _, pred = pred.max(dim=1)
        acc += (pred == batch.label).sum().float()
        size += len(pred)

    acc /= size
    acc = acc.cpu().data[0]
    return loss, acc

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BIMPM(nn.Module):
    def __init__(self, args, data):
        super(BIMPM, self).__init__()

        self.args = args
        self.d = self.args["word_dim"] + int(self.args["use_char_emb"]) * self.args["char_hidden_size"]
        self.l = self.args["num_perspective"]

        # ----- Word Representation Layer -----
        self.char_emb = nn.Embedding(args["char_vocab_size"], args["char_dim"], padding_idx=0)

        self.word_emb = nn.Embedding(args["word_vocab_size"], args["word_dim"])
        # initialize word embedding with GloVe
        self.word_emb.weight.data.copy_(data.TEXT.vocab.vectors)
        # no fine-tuning for word vectors
        self.word_emb.weight.requires_grad = False

        self.char_LSTM = nn.LSTM(
            input_size=self.args["char_dim"],
            hidden_size=self.args["char_hidden_size"],
            num_layers=1,
            bidirectional=False,
            batch_first=True)

        # ----- Context Representation Layer -----
        self.context_LSTM = nn.LSTM(
            input_size=self.d,
            hidden_size=self.args["hidden_size"],
            num_layers=1,
            bidirectional=True,
            batch_first=True
        )

        # ----- Matching Layer -----
        for i in range(1, 9):
            setattr(self, f'mp_w{i}',
                    nn.Parameter(torch.rand(self.l, self.args["hidden_size"])))

        # ----- Aggregation Layer -----
        self.aggregation_LSTM = nn.LSTM(
            input_size=self.l * 8,
            hidden_size=self.args["hidden_size"],
            num_layers=1,
            bidirectional=True,
            batch_first=True
        )

        # ----- Prediction Layer -----
        self.pred_fc1 = nn.Linear(self.args["hidden_size"] * 4, self.args["hidden_size"] * 2)
        self.pred_fc2 = nn.Linear(self.args["hidden_size"]* 2, self.args["class_size"])

        self.reset_parameters()

    def reset_parameters(self):
        # ----- Word Representation Layer -----
        nn.init.uniform(self.char_emb.weight, -0.005, 0.005)
        # zero vectors for padding
        self.char_emb.weight.data[0].fill_(0)

        # <unk> vectors is randomly initialized
        nn.init.uniform(self.word_emb.weight.data[0], -0.1, 0.1)

        nn.init.kaiming_normal(self.char_LSTM.weight_ih_l0)
        nn.init.constant(self.char_LSTM.bias_ih_l0, val=0)
        nn.init.orthogonal(self.char_LSTM.weight_hh_l0)
        nn.init.constant(self.char_LSTM.bias_hh_l0, val=0)

        # ----- Context Representation Layer -----
        nn.init.kaiming_normal(self.context_LSTM.weight_ih_l0)
        nn.init.constant(self.context_LSTM.bias_ih_l0, val=0)
        nn.init.orthogonal(self.context_LSTM.weight_hh_l0)
        nn.init.constant(self.context_LSTM.bias_hh_l0, val=0)

        nn.init.kaiming_normal(self.context_LSTM.weight_ih_l0_reverse)
        nn.init.constant(self.context_LSTM.bias_ih_l0_reverse, val=0)
        nn.init.orthogonal(self.context_LSTM.weight_hh_l0_reverse)
        nn.init.constant(self.context_LSTM.bias_hh_l0_reverse, val=0)

        # ----- Matching Layer -----
        for i in range(1, 9):
            w = getattr(self, f'mp_w{i}')
            nn.init.kaiming_normal(w)

        # ----- Aggregation Layer -----
        nn.init.kaiming_normal(self.aggregation_LSTM.weight_ih_l0)
        nn.init.constant(self.aggregation_LSTM.bias_ih_l0, val=0)
        nn.init.orthogonal(self.aggregation_LSTM.weight_hh_l0)
        nn.init.constant(self.aggregation_LSTM.bias_hh_l0, val=0)

        nn.init.kaiming_normal(self.aggregation_LSTM.weight_ih_l0_reverse)
        nn.init.constant(self.aggregation_LSTM.bias_ih_l0_reverse, val=0)
        nn.init.orthogonal(self.aggregation_LSTM.weight_hh_l0_reverse)
        nn.init.constant(self.aggregation_LSTM.bias_hh_l0_reverse, val=0)

        # ----- Prediction Layer ----
        nn.init.uniform(self.pred_fc1.weight, -0.005, 0.005)
        nn.init.constant(self.pred_fc1.bias, val=0)

        nn.init.uniform(self.pred_fc2.weight, -0.005, 0.005)
        nn.init.constant(self.pred_fc2.bias, val=0)

    def dropout(self, v):
        return F.dropout(v, p=self.args["dropout"], training=self.training)

    def forward(self, **kwargs):
        # ----- Matching Layer -----
        def mp_matching_func(v1, v2, w):
            """
            :param v1: (batch, seq_len, hidden_size)
            :param v2: (batch, seq_len, hidden_size) or (batch, hidden_size)
            :param w: (l, hidden_size)
            :return: (batch, l)
            """
            seq_len = v1.size(1)

            # Trick for large memory requirement
            """
            if len(v2.size()) == 2:
                v2 = torch.stack([v2] * seq_len, dim=1)

            m = []
            for i in range(self.l):
                # v1: (batch, seq_len, hidden_size)
                # v2: (batch, seq_len, hidden_size)
                # w: (1, 1, hidden_size)
                # -> (batch, seq_len)
                m.append(F.cosine_similarity(w[i].view(1, 1, -1) * v1, w[i].view(1, 1, -1) * v2, dim=2))

            # list of (batch, seq_len) -> (batch, seq_len, l)
            m = torch.stack(m, dim=2)
            """

            # (1, 1, hidden_size, l)
            w = w.transpose(1, 0).unsqueeze(0).unsqueeze(0)
            # (batch, seq_len, hidden_size, l)
            v1 = w * torch.stack([v1] * self.l, dim=3)
            if len(v2.size()) == 3:
                v2 = w * torch.stack([v2] * self.l, dim=3)
            else:
                v2 = w * torch.stack([torch.stack([v2] * seq_len, dim=1)] * self.l, dim=3)

            m = F.cosine_similarity(v1, v2, dim=2)

            return m

        def mp_matching_func_pairwise(v1, v2, w):
            """
            :param v1: (batch, seq_len1, hidden_size)
            :param v2: (batch, seq_len2, hidden_size)
            :param w: (l, hidden_size)
            :return: (batch, l, seq_len1, seq_len2)
            """

            # Trick for large memory requirement
            """
            m = []
            for i in range(self.l):
                # (1, 1, hidden_size)
                w_i = w[i].view(1, 1, -1)
                # (batch, seq_len1, hidden_size), (batch, seq_len2, hidden_size)
                v1, v2 = w_i * v1, w_i * v2
                # (batch, seq_len, hidden_size->1)
                v1_norm = v1.norm(p=2, dim=2, keepdim=True)
                v2_norm = v2.norm(p=2, dim=2, keepdim=True)

                # (batch, seq_len1, seq_len2)
                n = torch.matmul(v1, v2.permute(0, 2, 1))
                d = v1_norm * v2_norm.permute(0, 2, 1)

                m.append(div_with_small_value(n, d))

            # list of (batch, seq_len1, seq_len2) -> (batch, seq_len1, seq_len2, l)
            m = torch.stack(m, dim=3)
            """

            # (1, l, 1, hidden_size)
            w = w.unsqueeze(0).unsqueeze(2)
            # (batch, l, seq_len, hidden_size)
            v1, v2 = w * torch.stack([v1] * self.l, dim=1), w * torch.stack([v2] * self.l, dim=1)
            # (batch, l, seq_len, hidden_size->1)
            v1_norm = v1.norm(p=2, dim=3, keepdim=True)
            v2_norm = v2.norm(p=2, dim=3, keepdim=True)

            # (batch, l, seq_len1, seq_len2)
            n = torch.matmul(v1, v2.transpose(2, 3))
            d = v1_norm * v2_norm.transpose(2, 3)

            # (batch, seq_len1, seq_len2, l)
            m = div_with_small_value(n, d).permute(0, 2, 3, 1)

            return m

        def attention(v1, v2):
            """
            :param v1: (batch, seq_len1, hidden_size)
            :param v2: (batch, seq_len2, hidden_size)
            :return: (batch, seq_len1, seq_len2)
            """

            # (batch, seq_len1, 1)
            v1_norm = v1.norm(p=2, dim=2, keepdim=True)
            # (batch, 1, seq_len2)
            v2_norm = v2.norm(p=2, dim=2, keepdim=True).permute(0, 2, 1)

            # (batch, seq_len1, seq_len2)
            a = torch.bmm(v1, v2.permute(0, 2, 1))
            d = v1_norm * v2_norm

            return div_with_small_value(a, d)

        def div_with_small_value(n, d, eps=1e-8):
            # too small values are replaced by 1e-8 to prevent it from exploding.
            d = d * (d > eps).float() + eps * (d <= eps).float()
            return n / d

        # ----- Word Representation Layer -----
        # (batch, seq_len) -> (batch, seq_len, word_dim)

        p = self.word_emb(kwargs['p'])
        h = self.word_emb(kwargs['h'])

        if self.args["use_char_emb"]:
            # (batch, seq_len, max_word_len) -> (batch * seq_len, max_word_len)
            seq_len_p = kwargs['char_p'].size(1)
            seq_len_h = kwargs['char_h'].size(1)

            char_p = kwargs['char_p'].view(-1, self.args["max_word_len"])
            char_h = kwargs['char_h'].view(-1, self.args["max_word_len"])

            # (batch * seq_len, max_word_len, char_dim)-> (1, batch * seq_len, char_hidden_size)
            _, (char_p, _) = self.char_LSTM(self.char_emb(char_p))
            _, (char_h, _) = self.char_LSTM(self.char_emb(char_h))

            # (batch, seq_len, char_hidden_size)
            char_p = char_p.view(-1, seq_len_p, self.args["char_hidden_size"])
            char_h = char_h.view(-1, seq_len_h, self.args["char_hidden_size"])

            # (batch, seq_len, word_dim + char_hidden_size)
            p = torch.cat([p, char_p], dim=-1)
            h = torch.cat([h, char_h], dim=-1)

        p = self.dropout(p)
        h = self.dropout(h)

        # ----- Context Representation Layer -----
        # (batch, seq_len, hidden_size * 2)
        con_p, _ = self.context_LSTM(p)
        con_h, _ = self.context_LSTM(h)

        con_p = self.dropout(con_p)
        con_h = self.dropout(con_h)

        # (batch, seq_len, hidden_size)
        con_p_fw, con_p_bw = torch.split(con_p, self.args["hidden_size"], dim=-1)
        con_h_fw, con_h_bw = torch.split(con_h, self.args["hidden_size"], dim=-1)

        # 1. Full-Matching

        # (batch, seq_len, hidden_size), (batch, hidden_size)
        # -> (batch, seq_len, l)
        mv_p_full_fw = mp_matching_func(con_p_fw, con_h_fw[:, -1, :], self.mp_w1)
        mv_p_full_bw = mp_matching_func(con_p_bw, con_h_bw[:, 0, :], self.mp_w2)
        mv_h_full_fw = mp_matching_func(con_h_fw, con_p_fw[:, -1, :], self.mp_w1)
        mv_h_full_bw = mp_matching_func(con_h_bw, con_p_bw[:, 0, :], self.mp_w2)

        # 2. Maxpooling-Matching

        # (batch, seq_len1, seq_len2, l)
        mv_max_fw = mp_matching_func_pairwise(con_p_fw, con_h_fw, self.mp_w3)
        mv_max_bw = mp_matching_func_pairwise(con_p_bw, con_h_bw, self.mp_w4)

        # (batch, seq_len, l)
        mv_p_max_fw, _ = mv_max_fw.max(dim=2)
        mv_p_max_bw, _ = mv_max_bw.max(dim=2)
        mv_h_max_fw, _ = mv_max_fw.max(dim=1)
        mv_h_max_bw, _ = mv_max_bw.max(dim=1)

        # 3. Attentive-Matching

        # (batch, seq_len1, seq_len2)
        att_fw = attention(con_p_fw, con_h_fw)
        att_bw = attention(con_p_bw, con_h_bw)

        # (batch, seq_len2, hidden_size) -> (batch, 1, seq_len2, hidden_size)
        # (batch, seq_len1, seq_len2) -> (batch, seq_len1, seq_len2, 1)
        # -> (batch, seq_len1, seq_len2, hidden_size)
        att_h_fw = con_h_fw.unsqueeze(1) * att_fw.unsqueeze(3)
        att_h_bw = con_h_bw.unsqueeze(1) * att_bw.unsqueeze(3)
        # (batch, seq_len1, hidden_size) -> (batch, seq_len1, 1, hidden_size)
        # (batch, seq_len1, seq_len2) -> (batch, seq_len1, seq_len2, 1)
        # -> (batch, seq_len1, seq_len2, hidden_size)
        att_p_fw = con_p_fw.unsqueeze(2) * att_fw.unsqueeze(3)
        att_p_bw = con_p_bw.unsqueeze(2) * att_bw.unsqueeze(3)

        # (batch, seq_len1, hidden_size) / (batch, seq_len1, 1) -> (batch, seq_len1, hidden_size)
        att_mean_h_fw = div_with_small_value(att_h_fw.sum(dim=2), att_fw.sum(dim=2, keepdim=True))
        att_mean_h_bw = div_with_small_value(att_h_bw.sum(dim=2), att_bw.sum(dim=2, keepdim=True))

        # (batch, seq_len2, hidden_size) / (batch, seq_len2, 1) -> (batch, seq_len2, hidden_size)
        att_mean_p_fw = div_with_small_value(att_p_fw.sum(dim=1), att_fw.sum(dim=1, keepdim=True).permute(0, 2, 1))
        att_mean_p_bw = div_with_small_value(att_p_bw.sum(dim=1), att_bw.sum(dim=1, keepdim=True).permute(0, 2, 1))

        # (batch, seq_len, l)
        mv_p_att_mean_fw = mp_matching_func(con_p_fw, att_mean_h_fw, self.mp_w5)
        mv_p_att_mean_bw = mp_matching_func(con_p_bw, att_mean_h_bw, self.mp_w6)
        mv_h_att_mean_fw = mp_matching_func(con_h_fw, att_mean_p_fw, self.mp_w5)
        mv_h_att_mean_bw = mp_matching_func(con_h_bw, att_mean_p_bw, self.mp_w6)

        # 4. Max-Attentive-Matching

        # (batch, seq_len1, hidden_size)
        att_max_h_fw, _ = att_h_fw.max(dim=2)
        att_max_h_bw, _ = att_h_bw.max(dim=2)
        # (batch, seq_len2, hidden_size)
        att_max_p_fw, _ = att_p_fw.max(dim=1)
        att_max_p_bw, _ = att_p_bw.max(dim=1)

        # (batch, seq_len, l)
        mv_p_att_max_fw = mp_matching_func(con_p_fw, att_max_h_fw, self.mp_w7)
        mv_p_att_max_bw = mp_matching_func(con_p_bw, att_max_h_bw, self.mp_w8)
        mv_h_att_max_fw = mp_matching_func(con_h_fw, att_max_p_fw, self.mp_w7)
        mv_h_att_max_bw = mp_matching_func(con_h_bw, att_max_p_bw, self.mp_w8)

        # (batch, seq_len, l * 8)
        mv_p = torch.cat(
            [mv_p_full_fw, mv_p_max_fw, mv_p_att_mean_fw, mv_p_att_max_fw,
             mv_p_full_bw, mv_p_max_bw, mv_p_att_mean_bw, mv_p_att_max_bw], dim=2)
        mv_h = torch.cat(
            [mv_h_full_fw, mv_h_max_fw, mv_h_att_mean_fw, mv_h_att_max_fw,
             mv_h_full_bw, mv_h_max_bw, mv_h_att_mean_bw, mv_h_att_max_bw], dim=2)

        mv_p = self.dropout(mv_p)
        mv_h = self.dropout(mv_h)

        # ----- Aggregation Layer -----
        # (batch, seq_len, l * 8) -> (2, batch, hidden_size)
        _, (agg_p_last, _) = self.aggregation_LSTM(mv_p)
        _, (agg_h_last, _) = self.aggregation_LSTM(mv_h)

        # 2 * (2, batch, hidden_size) -> 2 * (batch, hidden_size * 2) -> (batch, hidden_size * 4)
        x = torch.cat(
            [agg_p_last.permute(1, 0, 2).contiguous().view(-1, self.args["hidden_size"] * 2),
             agg_h_last.permute(1, 0, 2).contiguous().view(-1, self.args["hidden_size"] * 2)], dim=1)
        x = self.dropout(x)

        # ----- Prediction Layer -----
        x = F.tanh(self.pred_fc1(x))
        x = self.dropout(x)
        x = self.pred_fc2(x)

        return x

# %%
from torchtext import data
from torchtext import datasets
from torchtext.vocab import GloVe

from nltk import word_tokenize


class SNLI():
    def __init__(self, args):
        self.TEXT = data.Field(batch_first=True, tokenize=word_tokenize, lower=True)
        self.LABEL = data.Field(sequential=False, unk_token=None)

        self.train, self.dev, self.test = datasets.SNLI.splits(self.TEXT, self.LABEL)

        self.TEXT.build_vocab(self.train, self.dev, self.test, vectors=FastText())
        self.LABEL.build_vocab(self.train)

        self.train_iter, self.dev_iter, self.test_iter = \
            data.BucketIterator.splits((self.train, self.dev, self.test),
                                       batch_sizes=[args["batch_size"]] * 3,
                                       device=args["gpu"])

        self.max_word_len = max([len(w) for w in self.TEXT.vocab.itos])
        # for <pad>
        self.char_vocab = {'': 0}
        # for <unk> and <pad>
        self.characterized_words = [[0] * self.max_word_len, [0] * self.max_word_len]

        if args["use_char_emb"]:
            self.build_char_vocab()

    def build_char_vocab(self):
        # for normal words
        for word in self.TEXT.vocab.itos[2:]:
            chars = []
            for c in list(word):
                if c not in self.char_vocab:
                    self.char_vocab[c] = len(self.char_vocab)

                chars.append(self.char_vocab[c])

            chars.extend([0] * (self.max_word_len - len(word)))
            self.characterized_words.append(chars)

    def characterize(self, batch):
        """
        :param batch: Pytorch Variable with shape (batch, seq_len)
        :return: Pytorch Variable with shape (batch, seq_len, max_word_len)
        """
        batch = batch.data.cpu().numpy().astype(int).tolist()
        return [[self.characterized_words[w] for w in words] for words in batch]

class Quora():
    def __init__(self, args):
        self.RAW = data.RawField()
        self.TEXT = data.Field(batch_first=True)
        self.LABEL = data.Field(sequential=False, unk_token=None)

        self.train, self.dev, self.test = data.TabularDataset.splits(
            path='',
            train='train.tsv',
            validation='dev.tsv',
            test='test.tsv',
            format='tsv',
            fields=[('label', self.LABEL),
                    ('q1', self.TEXT),
                    ('q2', self.TEXT),
                    ('id', self.RAW)])

        self.TEXT.build_vocab(self.train, self.dev, self.test, vectors=GloVe(name='840B', dim=300))
        self.LABEL.build_vocab(self.train)

        sort_key = lambda x: data.interleave_keys(len(x.q1), len(x.q2))

        self.train_iter, self.dev_iter, self.test_iter = \
            data.BucketIterator.splits((self.train, self.dev, self.test),
                                       batch_sizes=[args["batch_size"]] * 3,
                                       device=args["gpu"],
                                       sort_key=sort_key)

        self.max_word_len = max([len(w) for w in self.TEXT.vocab.itos])
        # for <pad>
        self.char_vocab = {'': 0}
        # for <unk> and <pad>
        self.characterized_words = [[0] * self.max_word_len, [0] * self.max_word_len]

        if args["use_char_emb"]:
            self.build_char_vocab()

    def build_char_vocab(self):
        # for normal words
        for word in self.TEXT.vocab.itos[2:]:
            chars = []
            for c in list(word):
                if c not in self.char_vocab:
                    self.char_vocab[c] = len(self.char_vocab)

                chars.append(self.char_vocab[c])

            chars.extend([0] * (self.max_word_len - len(word)))
            self.characterized_words.append(chars)

    def characterize(self, batch):
        """
        :param batch: Pytorch Variable with shape (batch, seq_len)
        :return: Pytorch Variable with shape (batch, seq_len, max_word_len)
        """
        batch = batch.data.cpu().numpy().astype(int).tolist()
        return [[self.characterized_words[w] for w in words] for words in batch]

# %%
import argparse
import copy
import os
import torch

from torch import nn, optim
from torch.autograd import Variable
from tensorboardX import SummaryWriter
from time import gmtime, strftime


def train(args, data):
    model = BIMPM(args, data)
    if args["gpu"] > -1:
        model.cuda(args["gpu"])

    parameters = filter(lambda p: p.requires_grad, model.parameters())
    optimizer = optim.Adam(parameters, lr=args["learning_rate"])
    criterion = nn.CrossEntropyLoss()

    writer = SummaryWriter(log_dir='runs/' + args["model_time"])

    model.train()
    loss, last_epoch = 0, -1
    max_dev_acc, max_test_acc = 0, 0

    iterator = data.train_iter
    for i, batch in enumerate(iterator):
        present_epoch = int(iterator.epoch)
        if present_epoch == args["epoch"]:
            break
        if present_epoch > last_epoch:
            print('epoch:', present_epoch + 1)
        last_epoch = present_epoch

        if args["data_type"] == 'SNLI':
            s1, s2 = 'premise', 'hypothesis'
        else:
            s1, s2 = 'q1', 'q2'

        s1, s2 = getattr(batch, s1), getattr(batch, s2)

        # limit the lengths of input sentences up to max_sent_len
        if args["max_sent_len"] >= 0:
            if s1.size()[1] > args["max_sent_len"]:
                s1 = s1[:, :args["max_sent_len"]]
            if s2.size()[1] > args["max_sent_len"]:
                s2 = s2[:, :args["max_sent_len"]]

        kwargs = {'p': s1, 'h': s2}

        if args["use_char_emb"]:
            char_p = Variable(torch.LongTensor(data.characterize(s1)))
            char_h = Variable(torch.LongTensor(data.characterize(s2)))

            if args["gpu"] > -1:
                char_p = char_p.cuda(args["gpu"])
                char_h = char_h.cuda(args["gpu"])

            kwargs['char_p'] = char_p
            kwargs['char_h'] = char_h

        pred = model(**kwargs)

        optimizer.zero_grad()
        batch_loss = criterion(pred, batch.label)
        loss += batch_loss.data[0]
        batch_loss.backward()
        optimizer.step()

        if (i + 1) % args["print_freq"] == 0:
            dev_loss, dev_acc = test(model, args, data, mode='dev')
            test_loss, test_acc = test(model, args, data)
            c = (i + 1) // args["print_freq"]

            writer.add_scalar('loss/train', loss, c)
            writer.add_scalar('loss/dev', dev_loss, c)
            writer.add_scalar('acc/dev', dev_acc, c)
            writer.add_scalar('loss/test', test_loss, c)
            writer.add_scalar('acc/test', test_acc, c)

            print(f'train loss: {loss:.3f} / dev loss: {dev_loss:.3f} / test loss: {test_loss:.3f}'
                  f' / dev acc: {dev_acc:.3f} / test acc: {test_acc:.3f}')

            if dev_acc > max_dev_acc:
                max_dev_acc = dev_acc
                max_test_acc = test_acc
                best_model = copy.deepcopy(model)

            loss = 0
            model.train()

    writer.close()
    print(f'max dev acc: {max_dev_acc:.3f} / max test acc: {max_test_acc:.3f}')

    return best_model


def main():
    args = {}
    args['batch_size'] = 16
    args['char_dim'] =  20
    args['char_hidden_size']=50
    args['data_type']='Quora'
    args['dropout'] = 0.1
    args['epoch'] = 10
    args['gpu'] =0
    args['hidden_size'] =100
    args['learning_rate'] =0.001
    args['max_sent_len'] =-1
    args['num_perspective'] =20
    args['print_freq'] =500
    args['use_char_emb'] =True
    args['word_dim'] = 300

    if args["data_type"] == 'SNLI':
        print('loading SNLI data...')
        data = SNLI(args)
    elif args["data_type"] == 'Quora':
        print('loading Quora data...')
        data = Quora(args)
    else:
        raise NotImplementedError('only SNLI or Quora data is possible')

    args['char_vocab_size']= len(data.char_vocab)
    args['word_vocab_size']= len(data.TEXT.vocab)
    args['class_size'] = len(data.LABEL.vocab)
    args['max_word_len'] = data.max_word_len
    args['model_time'] = strftime('%H:%M:%S', gmtime())

    print('training start!')
    best_model = train(args, data)

    if not os.path.exists('saved_models'):
        os.makedirs('saved_models')
    torch.save(best_model.state_dict(), f'saved_models/BIBPM_{args["data_type"]}_{args["model_time"]}.pt')

    print('training finished!')


if __name__ == '__main__':
    main()
# Out:
# loading Quora data...
# training start!
# epoch: 1
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: generator 'Iterator.__iter__' raised StopIteration
# train loss: 294.116 / dev loss: 365.919 / test loss: 366.395 / dev acc: 0.695 / test acc: 0.694
# train loss: 267.118 / dev loss: 340.868 / test loss: 340.693 / dev acc: 0.743 / test acc: 0.739
# train loss: 251.802 / dev loss: 302.176 / test loss: 304.081 / dev acc: 0.761 / test acc: 0.756
# train loss: 241.500 / dev loss: 323.051 / test loss: 323.336 / dev acc: 0.735 / test acc: 0.732
# train loss: 236.376 / dev loss: 297.370 / test loss: 295.429 / dev acc: 0.769 / test acc: 0.770
# train loss: 229.215 / dev loss: 286.249 / test loss: 285.967 / dev acc: 0.779 / test acc: 0.778
# train loss: 226.250 / dev loss: 289.787 / test loss: 286.820 / dev acc: 0.772 / test acc: 0.776
# train loss: 219.833 / dev loss: 279.176 / test loss: 277.041 / dev acc: 0.789 / test acc: 0.793
# train loss: 220.620 / dev loss: 276.858 / test loss: 273.338 / dev acc: 0.797 / test acc: 0.800
# train loss: 218.498 / dev loss: 273.302 / test loss: 270.187 / dev acc: 0.799 / test acc: 0.803
# train loss: 210.542 / dev loss: 276.321 / test loss: 274.779 / dev acc: 0.792 / test acc: 0.792
# train loss: 207.106 / dev loss: 272.649 / test loss: 268.596 / dev acc: 0.795 / test acc: 0.798
# train loss: 207.611 / dev loss: 277.565 / test loss: 274.627 / dev acc: 0.802 / test acc: 0.802
# train loss: 207.912 / dev loss: 270.173 / test loss: 267.675 / dev acc: 0.802 / test acc: 0.802
# train loss: 205.088 / dev loss: 261.639 / test loss: 259.669 / dev acc: 0.812 / test acc: 0.812
# train loss: 202.752 / dev loss: 257.082 / test loss: 256.016 / dev acc: 0.812 / test acc: 0.813
# train loss: 201.851 / dev loss: 253.713 / test loss: 253.070 / dev acc: 0.815 / test acc: 0.816
# train loss: 197.559 / dev loss: 251.274 / test loss: 249.032 / dev acc: 0.816 / test acc: 0.819
# train loss: 199.653 / dev loss: 253.307 / test loss: 251.510 / dev acc: 0.817 / test acc: 0.819
# train loss: 200.573 / dev loss: 257.931 / test loss: 257.283 / dev acc: 0.819 / test acc: 0.812
# train loss: 201.735 / dev loss: 249.072 / test loss: 249.712 / dev acc: 0.817 / test acc: 0.818
# train loss: 198.458 / dev loss: 249.661 / test loss: 250.606 / dev acc: 0.822 / test acc: 0.820
# train loss: 194.825 / dev loss: 246.601 / test loss: 246.719 / dev acc: 0.823 / test acc: 0.825
# train loss: 197.803 / dev loss: 253.924 / test loss: 255.937 / dev acc: 0.821 / test acc: 0.819
# train loss: 195.089 / dev loss: 248.770 / test loss: 246.078 / dev acc: 0.820 / test acc: 0.823
# train loss: 188.876 / dev loss: 245.497 / test loss: 243.032 / dev acc: 0.821 / test acc: 0.820
# train loss: 194.277 / dev loss: 247.395 / test loss: 245.457 / dev acc: 0.825 / test acc: 0.822
# train loss: 192.561 / dev loss: 243.921 / test loss: 243.885 / dev acc: 0.823 / test acc: 0.823
# train loss: 195.949 / dev loss: 238.474 / test loss: 236.899 / dev acc: 0.831 / test acc: 0.828
# train loss: 192.980 / dev loss: 238.128 / test loss: 236.507 / dev acc: 0.830 / test acc: 0.829
# train loss: 192.426 / dev loss: 242.938 / test loss: 240.784 / dev acc: 0.828 / test acc: 0.834
# train loss: 188.172 / dev loss: 249.651 / test loss: 247.572 / dev acc: 0.823 / test acc: 0.826
# train loss: 195.858 / dev loss: 235.167 / test loss: 233.009 / dev acc: 0.832 / test acc: 0.834
# train loss: 190.184 / dev loss: 234.619 / test loss: 231.596 / dev acc: 0.832 / test acc: 0.834
# train loss: 184.954 / dev loss: 239.990 / test loss: 238.056 / dev acc: 0.827 / test acc: 0.829
# train loss: 179.820 / dev loss: 236.257 / test loss: 235.598 / dev acc: 0.832 / test acc: 0.832
# train loss: 189.522 / dev loss: 239.486 / test loss: 238.553 / dev acc: 0.830 / test acc: 0.834
# train loss: 186.997 / dev loss: 236.487 / test loss: 236.325 / dev acc: 0.830 / test acc: 0.832
# train loss: 186.214 / dev loss: 232.118 / test loss: 231.339 / dev acc: 0.835 / test acc: 0.840
# train loss: 188.278 / dev loss: 230.961 / test loss: 231.117 / dev acc: 0.839 / test acc: 0.838
# train loss: 178.394 / dev loss: 232.125 / test loss: 232.367 / dev acc: 0.836 / test acc: 0.837
# train loss: 186.386 / dev loss: 227.394 / test loss: 224.370 / dev acc: 0.835 / test acc: 0.843
# train loss: 185.258 / dev loss: 225.438 / test loss: 224.868 / dev acc: 0.836 / test acc: 0.838
# train loss: 180.483 / dev loss: 229.769 / test loss: 230.317 / dev acc: 0.836 / test acc: 0.836
# train loss: 176.475 / dev loss: 224.109 / test loss: 223.851 / dev acc: 0.843 / test acc: 0.840
# train loss: 180.489 / dev loss: 232.251 / test loss: 233.244 / dev acc: 0.841 / test acc: 0.839
# train loss: 179.216 / dev loss: 224.463 / test loss: 225.322 / dev acc: 0.839 / test acc: 0.836
# train loss: 186.726 / dev loss: 229.728 / test loss: 230.392 / dev acc: 0.838 / test acc: 0.841
# epoch: 2
# train loss: 168.787 / dev loss: 224.279 / test loss: 225.230 / dev acc: 0.837 / test acc: 0.841
# train loss: 168.981 / dev loss: 222.458 / test loss: 220.921 / dev acc: 0.840 / test acc: 0.840
# train loss: 166.761 / dev loss: 229.106 / test loss: 229.089 / dev acc: 0.832 / test acc: 0.835
# train loss: 171.996 / dev loss: 226.594 / test loss: 227.014 / dev acc: 0.838 / test acc: 0.841
# train loss: 170.819 / dev loss: 231.643 / test loss: 233.070 / dev acc: 0.837 / test acc: 0.838
# train loss: 174.307 / dev loss: 220.155 / test loss: 222.340 / dev acc: 0.846 / test acc: 0.845
# train loss: 171.903 / dev loss: 222.875 / test loss: 224.766 / dev acc: 0.843 / test acc: 0.845
# train loss: 169.960 / dev loss: 219.767 / test loss: 220.832 / dev acc: 0.843 / test acc: 0.845
# train loss: 170.400 / dev loss: 222.550 / test loss: 222.623 / dev acc: 0.841 / test acc: 0.843
# train loss: 171.654 / dev loss: 216.516 / test loss: 217.254 / dev acc: 0.849 / test acc: 0.848
# train loss: 169.294 / dev loss: 228.444 / test loss: 231.830 / dev acc: 0.839 / test acc: 0.838
# train loss: 172.939 / dev loss: 224.021 / test loss: 225.724 / dev acc: 0.841 / test acc: 0.843
# train loss: 169.481 / dev loss: 216.312 / test loss: 218.306 / dev acc: 0.846 / test acc: 0.843
# train loss: 168.966 / dev loss: 225.249 / test loss: 226.326 / dev acc: 0.844 / test acc: 0.842
# train loss: 166.753 / dev loss: 220.675 / test loss: 220.875 / dev acc: 0.846 / test acc: 0.848
# train loss: 168.617 / dev loss: 222.800 / test loss: 225.068 / dev acc: 0.845 / test acc: 0.844
# train loss: 171.728 / dev loss: 219.333 / test loss: 223.187 / dev acc: 0.843 / test acc: 0.840
# train loss: 170.414 / dev loss: 230.439 / test loss: 232.960 / dev acc: 0.840 / test acc: 0.839
# train loss: 170.978 / dev loss: 217.481 / test loss: 218.287 / dev acc: 0.850 / test acc: 0.848
# train loss: 168.771 / dev loss: 223.253 / test loss: 223.141 / dev acc: 0.841 / test acc: 0.842
# train loss: 172.506 / dev loss: 221.182 / test loss: 220.624 / dev acc: 0.843 / test acc: 0.846
# train loss: 171.799 / dev loss: 221.597 / test loss: 223.555 / dev acc: 0.847 / test acc: 0.846
# train loss: 170.441 / dev loss: 230.294 / test loss: 230.817 / dev acc: 0.841 / test acc: 0.838
# train loss: 171.296 / dev loss: 215.964 / test loss: 218.893 / dev acc: 0.850 / test acc: 0.849
# train loss: 163.866 / dev loss: 212.295 / test loss: 214.328 / dev acc: 0.852 / test acc: 0.849
# train loss: 170.611 / dev loss: 225.205 / test loss: 224.650 / dev acc: 0.843 / test acc: 0.843
# train loss: 168.818 / dev loss: 226.926 / test loss: 226.381 / dev acc: 0.843 / test acc: 0.847
# train loss: 167.436 / dev loss: 221.102 / test loss: 221.569 / dev acc: 0.843 / test acc: 0.844
# train loss: 164.944 / dev loss: 219.969 / test loss: 220.065 / dev acc: 0.847 / test acc: 0.847
# train loss: 166.623 / dev loss: 218.394 / test loss: 218.242 / dev acc: 0.845 / test acc: 0.845
# train loss: 164.598 / dev loss: 216.397 / test loss: 215.092 / dev acc: 0.845 / test acc: 0.847
# train loss: 170.329 / dev loss: 217.209 / test loss: 213.894 / dev acc: 0.846 / test acc: 0.849
# train loss: 171.642 / dev loss: 215.817 / test loss: 215.279 / dev acc: 0.847 / test acc: 0.849
# train loss: 162.493 / dev loss: 214.989 / test loss: 215.098 / dev acc: 0.847 / test acc: 0.849
# train loss: 165.377 / dev loss: 220.006 / test loss: 220.886 / dev acc: 0.851 / test acc: 0.849
# train loss: 170.959 / dev loss: 218.539 / test loss: 221.037 / dev acc: 0.847 / test acc: 0.846
# train loss: 167.164 / dev loss: 219.702 / test loss: 219.286 / dev acc: 0.848 / test acc: 0.848
# train loss: 169.216 / dev loss: 216.420 / test loss: 215.631 / dev acc: 0.846 / test acc: 0.849
# train loss: 165.739 / dev loss: 218.116 / test loss: 216.817 / dev acc: 0.847 / test acc: 0.849
# train loss: 165.773 / dev loss: 217.260 / test loss: 216.626 / dev acc: 0.848 / test acc: 0.850
# train loss: 168.897 / dev loss: 224.371 / test loss: 222.767 / dev acc: 0.849 / test acc: 0.845
# train loss: 165.976 / dev loss: 213.008 / test loss: 211.357 / dev acc: 0.849 / test acc: 0.853
# train loss: 165.843 / dev loss: 213.373 / test loss: 210.687 / dev acc: 0.849 / test acc: 0.854
# train loss: 166.192 / dev loss: 222.394 / test loss: 218.562 / dev acc: 0.842 / test acc: 0.846
# train loss: 158.576 / dev loss: 225.654 / test loss: 222.583 / dev acc: 0.841 / test acc: 0.843
# train loss: 170.455 / dev loss: 213.564 / test loss: 209.425 / dev acc: 0.847 / test acc: 0.854
# train loss: 168.072 / dev loss: 227.750 / test loss: 225.383 / dev acc: 0.841 / test acc: 0.843
# train loss: 166.021 / dev loss: 222.847 / test loss: 220.377 / dev acc: 0.839 / test acc: 0.842
# epoch: 3
# train loss: 155.192 / dev loss: 212.965 / test loss: 211.739 / dev acc: 0.853 / test acc: 0.855
# train loss: 149.108 / dev loss: 213.867 / test loss: 212.049 / dev acc: 0.852 / test acc: 0.854
# train loss: 150.678 / dev loss: 221.398 / test loss: 218.671 / dev acc: 0.848 / test acc: 0.853
# train loss: 149.273 / dev loss: 214.173 / test loss: 211.819 / dev acc: 0.849 / test acc: 0.849
# train loss: 153.550 / dev loss: 217.469 / test loss: 215.671 / dev acc: 0.850 / test acc: 0.850
# train loss: 156.697 / dev loss: 211.921 / test loss: 208.859 / dev acc: 0.851 / test acc: 0.853
# train loss: 146.868 / dev loss: 213.011 / test loss: 211.426 / dev acc: 0.849 / test acc: 0.853
# train loss: 152.567 / dev loss: 206.934 / test loss: 205.222 / dev acc: 0.854 / test acc: 0.859
# train loss: 152.677 / dev loss: 218.249 / test loss: 216.628 / dev acc: 0.851 / test acc: 0.853
# train loss: 153.877 / dev loss: 208.261 / test loss: 208.745 / dev acc: 0.852 / test acc: 0.856
# train loss: 156.679 / dev loss: 210.865 / test loss: 208.658 / dev acc: 0.850 / test acc: 0.854
# train loss: 161.432 / dev loss: 206.117 / test loss: 205.104 / dev acc: 0.856 / test acc: 0.857
# train loss: 156.387 / dev loss: 212.628 / test loss: 212.352 / dev acc: 0.853 / test acc: 0.854
# train loss: 156.134 / dev loss: 214.730 / test loss: 213.303 / dev acc: 0.847 / test acc: 0.851
# train loss: 157.879 / dev loss: 219.009 / test loss: 216.272 / dev acc: 0.848 / test acc: 0.852
# train loss: 155.728 / dev loss: 214.388 / test loss: 215.147 / dev acc: 0.849 / test acc: 0.848
# train loss: 153.298 / dev loss: 207.916 / test loss: 206.451 / dev acc: 0.855 / test acc: 0.859
# train loss: 152.063 / dev loss: 216.730 / test loss: 215.374 / dev acc: 0.849 / test acc: 0.846
# train loss: 161.564 / dev loss: 216.557 / test loss: 213.768 / dev acc: 0.854 / test acc: 0.855
# train loss: 155.239 / dev loss: 210.112 / test loss: 209.546 / dev acc: 0.855 / test acc: 0.857
# train loss: 157.746 / dev loss: 208.642 / test loss: 207.174 / dev acc: 0.852 / test acc: 0.855
# train loss: 156.965 / dev loss: 210.482 / test loss: 209.237 / dev acc: 0.848 / test acc: 0.849
# train loss: 156.265 / dev loss: 213.013 / test loss: 214.480 / dev acc: 0.850 / test acc: 0.854
# train loss: 160.863 / dev loss: 205.509 / test loss: 206.917 / dev acc: 0.856 / test acc: 0.854
# train loss: 155.611 / dev loss: 210.365 / test loss: 210.783 / dev acc: 0.854 / test acc: 0.853
# train loss: 152.132 / dev loss: 203.898 / test loss: 203.880 / dev acc: 0.859 / test acc: 0.859
# train loss: 155.055 / dev loss: 211.722 / test loss: 212.278 / dev acc: 0.849 / test acc: 0.848
# train loss: 149.601 / dev loss: 210.455 / test loss: 210.176 / dev acc: 0.849 / test acc: 0.853
# train loss: 156.411 / dev loss: 204.802 / test loss: 201.477 / dev acc: 0.856 / test acc: 0.860
# train loss: 155.122 / dev loss: 211.696 / test loss: 211.623 / dev acc: 0.857 / test acc: 0.856
# train loss: 153.007 / dev loss: 206.957 / test loss: 207.369 / dev acc: 0.856 / test acc: 0.859
# train loss: 160.457 / dev loss: 208.524 / test loss: 208.704 / dev acc: 0.855 / test acc: 0.857
# train loss: 157.076 / dev loss: 206.568 / test loss: 206.099 / dev acc: 0.858 / test acc: 0.857
# train loss: 158.847 / dev loss: 204.550 / test loss: 204.574 / dev acc: 0.858 / test acc: 0.860
# train loss: 151.946 / dev loss: 207.572 / test loss: 209.122 / dev acc: 0.854 / test acc: 0.854
# train loss: 159.176 / dev loss: 209.115 / test loss: 207.462 / dev acc: 0.854 / test acc: 0.854
# train loss: 159.083 / dev loss: 208.371 / test loss: 207.841 / dev acc: 0.850 / test acc: 0.854
# train loss: 153.075 / dev loss: 204.528 / test loss: 205.542 / dev acc: 0.854 / test acc: 0.858
# train loss: 162.498 / dev loss: 202.413 / test loss: 204.110 / dev acc: 0.859 / test acc: 0.856
# train loss: 156.850 / dev loss: 216.046 / test loss: 215.793 / dev acc: 0.851 / test acc: 0.849
# train loss: 158.229 / dev loss: 206.979 / test loss: 208.859 / dev acc: 0.857 / test acc: 0.854
# train loss: 151.363 / dev loss: 200.247 / test loss: 200.305 / dev acc: 0.859 / test acc: 0.859
# train loss: 155.902 / dev loss: 208.453 / test loss: 209.087 / dev acc: 0.855 / test acc: 0.854
# train loss: 156.221 / dev loss: 224.477 / test loss: 224.503 / dev acc: 0.842 / test acc: 0.842
# train loss: 155.498 / dev loss: 205.595 / test loss: 206.701 / dev acc: 0.860 / test acc: 0.857
# train loss: 152.586 / dev loss: 209.527 / test loss: 211.828 / dev acc: 0.853 / test acc: 0.850
# train loss: 158.710 / dev loss: 209.654 / test loss: 212.721 / dev acc: 0.855 / test acc: 0.850
# train loss: 156.548 / dev loss: 202.693 / test loss: 207.803 / dev acc: 0.859 / test acc: 0.854
# epoch: 4
# train loss: 145.302 / dev loss: 202.875 / test loss: 205.103 / dev acc: 0.858 / test acc: 0.855
# train loss: 138.697 / dev loss: 203.052 / test loss: 203.979 / dev acc: 0.860 / test acc: 0.855
# train loss: 142.285 / dev loss: 201.734 / test loss: 201.829 / dev acc: 0.859 / test acc: 0.860
# train loss: 142.768 / dev loss: 201.445 / test loss: 202.334 / dev acc: 0.862 / test acc: 0.858
# train loss: 140.711 / dev loss: 210.907 / test loss: 209.925 / dev acc: 0.855 / test acc: 0.854
# train loss: 143.072 / dev loss: 205.464 / test loss: 205.557 / dev acc: 0.854 / test acc: 0.855
# train loss: 141.252 / dev loss: 206.527 / test loss: 206.308 / dev acc: 0.857 / test acc: 0.854
# train loss: 144.306 / dev loss: 216.640 / test loss: 216.811 / dev acc: 0.848 / test acc: 0.850
# train loss: 143.328 / dev loss: 216.108 / test loss: 217.447 / dev acc: 0.849 / test acc: 0.851
# train loss: 144.215 / dev loss: 202.313 / test loss: 202.156 / dev acc: 0.856 / test acc: 0.856
# train loss: 148.612 / dev loss: 203.230 / test loss: 203.918 / dev acc: 0.858 / test acc: 0.857
# train loss: 148.057 / dev loss: 217.946 / test loss: 219.454 / dev acc: 0.850 / test acc: 0.853
# train loss: 148.856 / dev loss: 206.907 / test loss: 208.223 / dev acc: 0.852 / test acc: 0.856
# train loss: 148.138 / dev loss: 205.390 / test loss: 206.319 / dev acc: 0.857 / test acc: 0.859
# train loss: 143.096 / dev loss: 205.000 / test loss: 205.765 / dev acc: 0.855 / test acc: 0.859
# train loss: 144.637 / dev loss: 206.450 / test loss: 206.634 / dev acc: 0.852 / test acc: 0.856
# train loss: 145.572 / dev loss: 204.563 / test loss: 206.355 / dev acc: 0.858 / test acc: 0.860
# train loss: 145.890 / dev loss: 203.159 / test loss: 202.086 / dev acc: 0.858 / test acc: 0.861
# train loss: 146.859 / dev loss: 207.662 / test loss: 207.008 / dev acc: 0.854 / test acc: 0.855
# train loss: 145.479 / dev loss: 203.006 / test loss: 201.604 / dev acc: 0.857 / test acc: 0.859
# train loss: 140.265 / dev loss: 212.637 / test loss: 214.029 / dev acc: 0.849 / test acc: 0.851
# train loss: 149.579 / dev loss: 200.362 / test loss: 201.110 / dev acc: 0.857 / test acc: 0.857
# train loss: 144.293 / dev loss: 202.563 / test loss: 202.078 / dev acc: 0.859 / test acc: 0.857
# train loss: 145.083 / dev loss: 201.612 / test loss: 202.347 / dev acc: 0.858 / test acc: 0.856
# train loss: 152.865 / dev loss: 202.474 / test loss: 204.428 / dev acc: 0.861 / test acc: 0.857
# train loss: 146.959 / dev loss: 203.309 / test loss: 202.953 / dev acc: 0.858 / test acc: 0.859
# train loss: 152.086 / dev loss: 196.143 / test loss: 199.613 / dev acc: 0.864 / test acc: 0.861
# train loss: 146.539 / dev loss: 203.814 / test loss: 205.766 / dev acc: 0.856 / test acc: 0.856
# train loss: 149.439 / dev loss: 205.890 / test loss: 207.455 / dev acc: 0.862 / test acc: 0.858
# train loss: 149.850 / dev loss: 202.839 / test loss: 204.000 / dev acc: 0.858 / test acc: 0.857
# train loss: 149.625 / dev loss: 198.337 / test loss: 200.648 / dev acc: 0.860 / test acc: 0.856
# train loss: 146.071 / dev loss: 195.797 / test loss: 197.867 / dev acc: 0.863 / test acc: 0.861
# train loss: 146.874 / dev loss: 205.276 / test loss: 208.440 / dev acc: 0.857 / test acc: 0.857
# train loss: 149.268 / dev loss: 207.924 / test loss: 210.365 / dev acc: 0.857 / test acc: 0.855
# train loss: 145.380 / dev loss: 199.815 / test loss: 199.936 / dev acc: 0.860 / test acc: 0.861
# train loss: 148.188 / dev loss: 216.073 / test loss: 215.162 / dev acc: 0.850 / test acc: 0.850
# train loss: 152.052 / dev loss: 198.967 / test loss: 200.201 / dev acc: 0.864 / test acc: 0.863
# train loss: 152.664 / dev loss: 204.014 / test loss: 204.133 / dev acc: 0.860 / test acc: 0.855
# train loss: 154.006 / dev loss: 206.679 / test loss: 206.947 / dev acc: 0.859 / test acc: 0.859
# train loss: 149.211 / dev loss: 210.583 / test loss: 211.966 / dev acc: 0.852 / test acc: 0.852
# train loss: 146.343 / dev loss: 203.936 / test loss: 202.840 / dev acc: 0.855 / test acc: 0.858
# train loss: 152.513 / dev loss: 207.001 / test loss: 205.147 / dev acc: 0.854 / test acc: 0.861
# train loss: 151.660 / dev loss: 207.236 / test loss: 207.239 / dev acc: 0.859 / test acc: 0.859
# train loss: 151.075 / dev loss: 216.520 / test loss: 218.117 / dev acc: 0.851 / test acc: 0.849
# train loss: 148.772 / dev loss: 206.199 / test loss: 206.024 / dev acc: 0.854 / test acc: 0.855
# train loss: 151.246 / dev loss: 202.908 / test loss: 201.775 / dev acc: 0.857 / test acc: 0.860
# train loss: 151.495 / dev loss: 195.536 / test loss: 196.711 / dev acc: 0.861 / test acc: 0.860
# train loss: 147.595 / dev loss: 199.716 / test loss: 200.301 / dev acc: 0.858 / test acc: 0.860
# epoch: 5
# train loss: 135.969 / dev loss: 205.211 / test loss: 207.940 / dev acc: 0.855 / test acc: 0.851
# train loss: 133.082 / dev loss: 203.992 / test loss: 207.776 / dev acc: 0.857 / test acc: 0.854
# train loss: 143.471 / dev loss: 213.235 / test loss: 216.259 / dev acc: 0.848 / test acc: 0.845
# train loss: 136.943 / dev loss: 199.056 / test loss: 201.929 / dev acc: 0.864 / test acc: 0.858
# train loss: 140.406 / dev loss: 198.990 / test loss: 202.755 / dev acc: 0.860 / test acc: 0.859
# train loss: 139.453 / dev loss: 202.559 / test loss: 205.572 / dev acc: 0.859 / test acc: 0.859
# train loss: 141.673 / dev loss: 200.741 / test loss: 202.283 / dev acc: 0.860 / test acc: 0.858
# train loss: 136.799 / dev loss: 212.925 / test loss: 213.194 / dev acc: 0.852 / test acc: 0.849
# train loss: 142.421 / dev loss: 200.986 / test loss: 199.430 / dev acc: 0.857 / test acc: 0.859
# train loss: 145.061 / dev loss: 210.470 / test loss: 210.463 / dev acc: 0.853 / test acc: 0.854
# train loss: 133.825 / dev loss: 203.577 / test loss: 202.991 / dev acc: 0.860 / test acc: 0.858
# train loss: 136.580 / dev loss: 200.674 / test loss: 201.415 / dev acc: 0.863 / test acc: 0.862
# train loss: 143.769 / dev loss: 199.460 / test loss: 201.681 / dev acc: 0.863 / test acc: 0.858
# train loss: 137.019 / dev loss: 203.862 / test loss: 204.248 / dev acc: 0.858 / test acc: 0.860
# train loss: 144.329 / dev loss: 196.165 / test loss: 195.070 / dev acc: 0.863 / test acc: 0.865
# train loss: 139.414 / dev loss: 201.861 / test loss: 197.745 / dev acc: 0.862 / test acc: 0.865
# train loss: 136.940 / dev loss: 210.194 / test loss: 209.872 / dev acc: 0.859 / test acc: 0.857
# train loss: 136.790 / dev loss: 207.618 / test loss: 208.536 / dev acc: 0.860 / test acc: 0.857
# train loss: 134.987 / dev loss: 221.110 / test loss: 223.671 / dev acc: 0.851 / test acc: 0.851
# train loss: 142.727 / dev loss: 195.320 / test loss: 197.543 / dev acc: 0.865 / test acc: 0.862
# train loss: 137.965 / dev loss: 204.317 / test loss: 203.883 / dev acc: 0.860 / test acc: 0.857
# train loss: 144.850 / dev loss: 198.621 / test loss: 196.778 / dev acc: 0.864 / test acc: 0.865
# train loss: 142.820 / dev loss: 200.855 / test loss: 200.411 / dev acc: 0.861 / test acc: 0.861
# train loss: 134.321 / dev loss: 195.511 / test loss: 195.496 / dev acc: 0.866 / test acc: 0.864
# train loss: 148.162 / dev loss: 205.750 / test loss: 206.878 / dev acc: 0.859 / test acc: 0.857
# train loss: 140.602 / dev loss: 200.581 / test loss: 200.915 / dev acc: 0.860 / test acc: 0.861
# train loss: 139.145 / dev loss: 204.135 / test loss: 204.753 / dev acc: 0.858 / test acc: 0.859
# train loss: 140.754 / dev loss: 201.265 / test loss: 203.354 / dev acc: 0.863 / test acc: 0.858
# train loss: 142.744 / dev loss: 201.499 / test loss: 203.467 / dev acc: 0.862 / test acc: 0.855
# train loss: 146.731 / dev loss: 200.565 / test loss: 203.497 / dev acc: 0.860 / test acc: 0.857
# train loss: 142.512 / dev loss: 201.540 / test loss: 201.544 / dev acc: 0.861 / test acc: 0.862
# train loss: 141.221 / dev loss: 198.603 / test loss: 199.552 / dev acc: 0.862 / test acc: 0.862
# train loss: 141.541 / dev loss: 201.161 / test loss: 202.310 / dev acc: 0.863 / test acc: 0.861
# train loss: 144.531 / dev loss: 200.094 / test loss: 204.163 / dev acc: 0.862 / test acc: 0.861
# train loss: 144.941 / dev loss: 207.540 / test loss: 211.263 / dev acc: 0.859 / test acc: 0.856
# train loss: 139.030 / dev loss: 196.367 / test loss: 199.281 / dev acc: 0.863 / test acc: 0.862
# train loss: 145.228 / dev loss: 196.672 / test loss: 200.326 / dev acc: 0.866 / test acc: 0.862
# train loss: 144.031 / dev loss: 197.422 / test loss: 200.322 / dev acc: 0.863 / test acc: 0.862
# train loss: 138.844 / dev loss: 200.887 / test loss: 204.945 / dev acc: 0.860 / test acc: 0.859
# train loss: 143.802 / dev loss: 194.677 / test loss: 196.765 / dev acc: 0.861 / test acc: 0.863
# train loss: 139.148 / dev loss: 190.876 / test loss: 196.065 / dev acc: 0.868 / test acc: 0.867
# train loss: 144.554 / dev loss: 191.122 / test loss: 194.974 / dev acc: 0.866 / test acc: 0.869
# train loss: 141.185 / dev loss: 196.147 / test loss: 198.627 / dev acc: 0.862 / test acc: 0.864
# train loss: 144.866 / dev loss: 190.148 / test loss: 191.587 / dev acc: 0.869 / test acc: 0.867
# train loss: 141.023 / dev loss: 195.339 / test loss: 200.098 / dev acc: 0.867 / test acc: 0.861
# train loss: 146.350 / dev loss: 199.386 / test loss: 205.483 / dev acc: 0.863 / test acc: 0.858
# train loss: 144.402 / dev loss: 194.342 / test loss: 197.764 / dev acc: 0.868 / test acc: 0.864
# train loss: 137.635 / dev loss: 200.695 / test loss: 205.211 / dev acc: 0.862 / test acc: 0.859
# epoch: 6
# train loss: 134.520 / dev loss: 197.066 / test loss: 199.643 / dev acc: 0.865 / test acc: 0.863
# train loss: 135.182 / dev loss: 198.748 / test loss: 201.835 / dev acc: 0.863 / test acc: 0.862
# train loss: 131.066 / dev loss: 191.701 / test loss: 192.458 / dev acc: 0.866 / test acc: 0.871
# train loss: 131.042 / dev loss: 194.976 / test loss: 197.253 / dev acc: 0.865 / test acc: 0.863
# train loss: 131.353 / dev loss: 197.443 / test loss: 197.595 / dev acc: 0.861 / test acc: 0.866
# train loss: 133.582 / dev loss: 195.308 / test loss: 196.506 / dev acc: 0.863 / test acc: 0.866
# train loss: 134.428 / dev loss: 203.066 / test loss: 203.391 / dev acc: 0.859 / test acc: 0.861
# train loss: 136.108 / dev loss: 202.053 / test loss: 203.516 / dev acc: 0.861 / test acc: 0.861
# train loss: 136.920 / dev loss: 197.836 / test loss: 200.118 / dev acc: 0.861 / test acc: 0.864
# train loss: 135.823 / dev loss: 201.790 / test loss: 204.707 / dev acc: 0.858 / test acc: 0.860
# train loss: 134.265 / dev loss: 195.887 / test loss: 199.659 / dev acc: 0.860 / test acc: 0.862
# train loss: 130.486 / dev loss: 196.299 / test loss: 200.279 / dev acc: 0.860 / test acc: 0.863
# train loss: 129.611 / dev loss: 199.833 / test loss: 204.043 / dev acc: 0.861 / test acc: 0.861
# train loss: 130.227 / dev loss: 197.352 / test loss: 202.932 / dev acc: 0.864 / test acc: 0.861
# train loss: 131.108 / dev loss: 195.685 / test loss: 200.701 / dev acc: 0.866 / test acc: 0.861
# train loss: 138.180 / dev loss: 195.202 / test loss: 199.044 / dev acc: 0.864 / test acc: 0.861
# train loss: 137.915 / dev loss: 196.284 / test loss: 198.733 / dev acc: 0.862 / test acc: 0.864
# train loss: 140.428 / dev loss: 198.292 / test loss: 200.432 / dev acc: 0.862 / test acc: 0.862
# train loss: 136.166 / dev loss: 198.069 / test loss: 199.207 / dev acc: 0.862 / test acc: 0.862
# train loss: 139.264 / dev loss: 199.783 / test loss: 201.496 / dev acc: 0.862 / test acc: 0.861
# train loss: 135.805 / dev loss: 198.371 / test loss: 200.618 / dev acc: 0.863 / test acc: 0.862
# train loss: 136.281 / dev loss: 193.189 / test loss: 195.266 / dev acc: 0.865 / test acc: 0.863
# train loss: 138.218 / dev loss: 199.819 / test loss: 203.573 / dev acc: 0.862 / test acc: 0.859
# train loss: 133.514 / dev loss: 201.961 / test loss: 204.699 / dev acc: 0.863 / test acc: 0.861
# train loss: 133.560 / dev loss: 196.111 / test loss: 200.248 / dev acc: 0.867 / test acc: 0.861
# train loss: 144.223 / dev loss: 193.217 / test loss: 193.798 / dev acc: 0.867 / test acc: 0.864
# train loss: 138.966 / dev loss: 190.844 / test loss: 194.338 / dev acc: 0.870 / test acc: 0.863
# train loss: 131.179 / dev loss: 193.139 / test loss: 197.743 / dev acc: 0.864 / test acc: 0.863
# train loss: 132.480 / dev loss: 201.941 / test loss: 206.838 / dev acc: 0.860 / test acc: 0.858
# train loss: 138.543 / dev loss: 190.178 / test loss: 193.232 / dev acc: 0.868 / test acc: 0.869
# train loss: 138.004 / dev loss: 196.235 / test loss: 201.950 / dev acc: 0.864 / test acc: 0.861
# train loss: 140.962 / dev loss: 193.213 / test loss: 197.132 / dev acc: 0.865 / test acc: 0.862
# train loss: 137.862 / dev loss: 194.029 / test loss: 196.892 / dev acc: 0.868 / test acc: 0.862
# train loss: 140.880 / dev loss: 197.865 / test loss: 200.327 / dev acc: 0.865 / test acc: 0.861
# train loss: 139.173 / dev loss: 204.076 / test loss: 207.243 / dev acc: 0.862 / test acc: 0.856
# train loss: 135.037 / dev loss: 195.174 / test loss: 198.999 / dev acc: 0.866 / test acc: 0.863
# train loss: 138.571 / dev loss: 193.595 / test loss: 198.415 / dev acc: 0.865 / test acc: 0.860
# train loss: 135.781 / dev loss: 195.748 / test loss: 200.445 / dev acc: 0.867 / test acc: 0.861
# train loss: 140.151 / dev loss: 198.239 / test loss: 203.676 / dev acc: 0.868 / test acc: 0.860
# train loss: 141.105 / dev loss: 196.719 / test loss: 200.697 / dev acc: 0.867 / test acc: 0.861
# train loss: 142.546 / dev loss: 194.666 / test loss: 197.280 / dev acc: 0.868 / test acc: 0.869
# train loss: 137.313 / dev loss: 196.136 / test loss: 200.965 / dev acc: 0.866 / test acc: 0.866
# train loss: 141.283 / dev loss: 194.869 / test loss: 202.408 / dev acc: 0.865 / test acc: 0.861
# train loss: 133.714 / dev loss: 186.972 / test loss: 193.277 / dev acc: 0.872 / test acc: 0.868
# train loss: 144.974 / dev loss: 195.461 / test loss: 200.695 / dev acc: 0.870 / test acc: 0.865
# train loss: 140.173 / dev loss: 193.153 / test loss: 200.866 / dev acc: 0.869 / test acc: 0.861
# train loss: 138.566 / dev loss: 190.827 / test loss: 197.836 / dev acc: 0.869 / test acc: 0.864
# train loss: 143.924 / dev loss: 203.877 / test loss: 210.248 / dev acc: 0.860 / test acc: 0.854
# epoch: 7
# train loss: 133.436 / dev loss: 192.222 / test loss: 195.634 / dev acc: 0.870 / test acc: 0.866
# train loss: 129.787 / dev loss: 189.980 / test loss: 195.454 / dev acc: 0.870 / test acc: 0.864
# train loss: 127.036 / dev loss: 189.307 / test loss: 193.351 / dev acc: 0.871 / test acc: 0.869
# train loss: 131.945 / dev loss: 193.370 / test loss: 199.087 / dev acc: 0.868 / test acc: 0.865
# train loss: 128.109 / dev loss: 200.124 / test loss: 207.622 / dev acc: 0.862 / test acc: 0.861
# train loss: 128.770 / dev loss: 190.234 / test loss: 195.302 / dev acc: 0.871 / test acc: 0.868
# train loss: 125.843 / dev loss: 199.270 / test loss: 205.701 / dev acc: 0.867 / test acc: 0.861
# train loss: 131.245 / dev loss: 194.116 / test loss: 198.159 / dev acc: 0.868 / test acc: 0.866
# train loss: 129.552 / dev loss: 196.327 / test loss: 203.612 / dev acc: 0.867 / test acc: 0.860
# train loss: 130.032 / dev loss: 201.733 / test loss: 205.744 / dev acc: 0.865 / test acc: 0.862
# train loss: 129.946 / dev loss: 196.963 / test loss: 200.044 / dev acc: 0.862 / test acc: 0.861
# train loss: 133.926 / dev loss: 195.764 / test loss: 200.889 / dev acc: 0.867 / test acc: 0.864
# train loss: 132.048 / dev loss: 193.727 / test loss: 197.640 / dev acc: 0.863 / test acc: 0.865
# train loss: 135.358 / dev loss: 202.088 / test loss: 206.612 / dev acc: 0.863 / test acc: 0.857
# train loss: 130.569 / dev loss: 199.710 / test loss: 203.933 / dev acc: 0.864 / test acc: 0.861
# train loss: 134.666 / dev loss: 194.283 / test loss: 196.721 / dev acc: 0.868 / test acc: 0.868
# train loss: 130.689 / dev loss: 195.764 / test loss: 199.276 / dev acc: 0.867 / test acc: 0.864
# train loss: 128.318 / dev loss: 192.459 / test loss: 197.063 / dev acc: 0.868 / test acc: 0.863
# train loss: 128.354 / dev loss: 201.758 / test loss: 205.856 / dev acc: 0.867 / test acc: 0.859
# train loss: 131.612 / dev loss: 196.466 / test loss: 198.056 / dev acc: 0.867 / test acc: 0.864
# train loss: 131.207 / dev loss: 194.277 / test loss: 199.141 / dev acc: 0.868 / test acc: 0.862
# train loss: 131.863 / dev loss: 203.861 / test loss: 206.813 / dev acc: 0.863 / test acc: 0.858
# train loss: 136.094 / dev loss: 192.431 / test loss: 198.942 / dev acc: 0.869 / test acc: 0.863
# train loss: 137.619 / dev loss: 190.413 / test loss: 195.332 / dev acc: 0.868 / test acc: 0.864
# train loss: 131.154 / dev loss: 192.375 / test loss: 196.340 / dev acc: 0.867 / test acc: 0.866
# train loss: 134.084 / dev loss: 190.673 / test loss: 197.425 / dev acc: 0.867 / test acc: 0.864
# train loss: 134.010 / dev loss: 195.037 / test loss: 197.238 / dev acc: 0.865 / test acc: 0.866
# train loss: 130.785 / dev loss: 194.099 / test loss: 196.507 / dev acc: 0.864 / test acc: 0.865
# train loss: 141.799 / dev loss: 197.515 / test loss: 198.139 / dev acc: 0.862 / test acc: 0.862
# train loss: 132.573 / dev loss: 202.013 / test loss: 201.568 / dev acc: 0.861 / test acc: 0.861
# train loss: 133.382 / dev loss: 194.720 / test loss: 195.162 / dev acc: 0.864 / test acc: 0.867
# train loss: 138.350 / dev loss: 207.385 / test loss: 208.334 / dev acc: 0.857 / test acc: 0.859
# train loss: 135.638 / dev loss: 193.958 / test loss: 195.205 / dev acc: 0.865 / test acc: 0.863
# train loss: 132.676 / dev loss: 198.387 / test loss: 198.361 / dev acc: 0.861 / test acc: 0.861
# train loss: 138.377 / dev loss: 197.797 / test loss: 200.656 / dev acc: 0.863 / test acc: 0.863
# train loss: 137.434 / dev loss: 196.406 / test loss: 199.308 / dev acc: 0.865 / test acc: 0.864
# train loss: 139.418 / dev loss: 202.226 / test loss: 202.884 / dev acc: 0.858 / test acc: 0.859
# train loss: 133.058 / dev loss: 200.256 / test loss: 199.764 / dev acc: 0.864 / test acc: 0.862
# train loss: 137.756 / dev loss: 191.404 / test loss: 189.573 / dev acc: 0.868 / test acc: 0.870
# train loss: 137.972 / dev loss: 195.562 / test loss: 194.002 / dev acc: 0.866 / test acc: 0.869
# train loss: 130.116 / dev loss: 203.889 / test loss: 201.028 / dev acc: 0.860 / test acc: 0.862
# train loss: 133.413 / dev loss: 198.489 / test loss: 197.155 / dev acc: 0.864 / test acc: 0.867
# train loss: 140.193 / dev loss: 201.558 / test loss: 200.262 / dev acc: 0.862 / test acc: 0.864
# train loss: 131.050 / dev loss: 195.943 / test loss: 194.269 / dev acc: 0.867 / test acc: 0.870
# train loss: 133.858 / dev loss: 196.653 / test loss: 194.394 / dev acc: 0.865 / test acc: 0.868
# train loss: 134.445 / dev loss: 202.157 / test loss: 200.185 / dev acc: 0.863 / test acc: 0.868
# train loss: 134.499 / dev loss: 194.644 / test loss: 193.626 / dev acc: 0.869 / test acc: 0.867
# train loss: 138.617 / dev loss: 200.520 / test loss: 198.847 / dev acc: 0.866 / test acc: 0.866
# epoch: 8
# train loss: 133.473 / dev loss: 200.527 / test loss: 199.454 / dev acc: 0.865 / test acc: 0.866
# train loss: 122.326 / dev loss: 202.821 / test loss: 199.132 / dev acc: 0.862 / test acc: 0.864
# train loss: 120.349 / dev loss: 200.557 / test loss: 199.381 / dev acc: 0.864 / test acc: 0.862
# train loss: 124.965 / dev loss: 201.423 / test loss: 200.755 / dev acc: 0.864 / test acc: 0.864
# train loss: 125.944 / dev loss: 195.860 / test loss: 194.264 / dev acc: 0.868 / test acc: 0.868
# train loss: 128.217 / dev loss: 199.405 / test loss: 197.378 / dev acc: 0.866 / test acc: 0.865
# train loss: 126.873 / dev loss: 195.615 / test loss: 192.958 / dev acc: 0.867 / test acc: 0.866
# train loss: 124.373 / dev loss: 196.591 / test loss: 193.085 / dev acc: 0.867 / test acc: 0.868
# train loss: 126.963 / dev loss: 202.773 / test loss: 198.163 / dev acc: 0.865 / test acc: 0.865
# train loss: 126.892 / dev loss: 194.966 / test loss: 192.685 / dev acc: 0.868 / test acc: 0.866
# train loss: 132.247 / dev loss: 196.925 / test loss: 195.621 / dev acc: 0.870 / test acc: 0.869
# train loss: 128.075 / dev loss: 195.375 / test loss: 194.047 / dev acc: 0.869 / test acc: 0.870
# train loss: 119.940 / dev loss: 200.262 / test loss: 198.345 / dev acc: 0.864 / test acc: 0.867
# train loss: 126.200 / dev loss: 198.934 / test loss: 194.993 / dev acc: 0.866 / test acc: 0.866
# train loss: 129.294 / dev loss: 202.192 / test loss: 199.991 / dev acc: 0.867 / test acc: 0.863
# train loss: 127.476 / dev loss: 196.200 / test loss: 193.151 / dev acc: 0.866 / test acc: 0.866
# train loss: 126.280 / dev loss: 193.681 / test loss: 193.616 / dev acc: 0.869 / test acc: 0.868
# train loss: 130.643 / dev loss: 197.652 / test loss: 194.915 / dev acc: 0.867 / test acc: 0.869
# train loss: 124.304 / dev loss: 199.813 / test loss: 196.555 / dev acc: 0.865 / test acc: 0.866
# train loss: 128.776 / dev loss: 193.565 / test loss: 193.079 / dev acc: 0.868 / test acc: 0.867
# train loss: 130.415 / dev loss: 195.678 / test loss: 197.925 / dev acc: 0.866 / test acc: 0.865
# train loss: 134.580 / dev loss: 193.960 / test loss: 192.912 / dev acc: 0.865 / test acc: 0.867
# train loss: 127.471 / dev loss: 208.178 / test loss: 208.496 / dev acc: 0.864 / test acc: 0.862
# train loss: 132.804 / dev loss: 197.242 / test loss: 194.981 / dev acc: 0.865 / test acc: 0.868
# train loss: 129.243 / dev loss: 194.238 / test loss: 192.982 / dev acc: 0.869 / test acc: 0.868
# train loss: 132.253 / dev loss: 195.782 / test loss: 196.075 / dev acc: 0.867 / test acc: 0.868
# train loss: 128.154 / dev loss: 196.614 / test loss: 194.436 / dev acc: 0.868 / test acc: 0.868
# train loss: 128.353 / dev loss: 197.532 / test loss: 197.102 / dev acc: 0.865 / test acc: 0.863
# train loss: 128.281 / dev loss: 205.852 / test loss: 207.329 / dev acc: 0.864 / test acc: 0.861
# train loss: 139.556 / dev loss: 194.722 / test loss: 194.977 / dev acc: 0.868 / test acc: 0.864
# train loss: 130.834 / dev loss: 193.240 / test loss: 195.851 / dev acc: 0.868 / test acc: 0.868
# train loss: 133.746 / dev loss: 199.542 / test loss: 200.011 / dev acc: 0.864 / test acc: 0.864
# train loss: 130.590 / dev loss: 204.106 / test loss: 203.060 / dev acc: 0.863 / test acc: 0.866
# train loss: 133.234 / dev loss: 200.249 / test loss: 199.572 / dev acc: 0.862 / test acc: 0.861
# train loss: 131.509 / dev loss: 195.754 / test loss: 197.188 / dev acc: 0.865 / test acc: 0.864
# train loss: 135.694 / dev loss: 204.821 / test loss: 203.833 / dev acc: 0.859 / test acc: 0.858
# train loss: 130.223 / dev loss: 200.628 / test loss: 199.514 / dev acc: 0.865 / test acc: 0.865
# train loss: 134.196 / dev loss: 195.015 / test loss: 196.922 / dev acc: 0.863 / test acc: 0.864
# train loss: 133.163 / dev loss: 190.788 / test loss: 192.780 / dev acc: 0.868 / test acc: 0.869
# train loss: 138.532 / dev loss: 196.333 / test loss: 198.252 / dev acc: 0.866 / test acc: 0.862
# train loss: 132.187 / dev loss: 197.928 / test loss: 196.636 / dev acc: 0.864 / test acc: 0.866
# train loss: 138.492 / dev loss: 194.996 / test loss: 195.121 / dev acc: 0.869 / test acc: 0.864
# train loss: 136.428 / dev loss: 203.552 / test loss: 201.914 / dev acc: 0.859 / test acc: 0.860
# train loss: 137.830 / dev loss: 194.007 / test loss: 195.678 / dev acc: 0.867 / test acc: 0.864
# train loss: 132.936 / dev loss: 192.027 / test loss: 191.415 / dev acc: 0.869 / test acc: 0.867
# train loss: 129.350 / dev loss: 202.579 / test loss: 200.367 / dev acc: 0.868 / test acc: 0.866
# train loss: 136.012 / dev loss: 197.839 / test loss: 196.108 / dev acc: 0.865 / test acc: 0.866
# train loss: 130.012 / dev loss: 204.003 / test loss: 201.257 / dev acc: 0.865 / test acc: 0.864
# epoch: 9
# train loss: 129.891 / dev loss: 200.967 / test loss: 200.715 / dev acc: 0.865 / test acc: 0.862
# train loss: 120.927 / dev loss: 197.323 / test loss: 197.205 / dev acc: 0.867 / test acc: 0.865
# train loss: 124.546 / dev loss: 197.435 / test loss: 195.933 / dev acc: 0.866 / test acc: 0.866
# train loss: 123.681 / dev loss: 202.135 / test loss: 198.462 / dev acc: 0.864 / test acc: 0.868
# train loss: 124.418 / dev loss: 197.709 / test loss: 194.386 / dev acc: 0.863 / test acc: 0.868
# train loss: 125.299 / dev loss: 204.465 / test loss: 200.535 / dev acc: 0.864 / test acc: 0.867
# train loss: 128.020 / dev loss: 193.261 / test loss: 191.442 / dev acc: 0.866 / test acc: 0.869
# train loss: 126.594 / dev loss: 194.940 / test loss: 192.124 / dev acc: 0.867 / test acc: 0.868
# train loss: 130.260 / dev loss: 200.237 / test loss: 200.069 / dev acc: 0.864 / test acc: 0.865
# train loss: 118.266 / dev loss: 202.341 / test loss: 198.877 / dev acc: 0.864 / test acc: 0.864
# train loss: 123.166 / dev loss: 198.091 / test loss: 198.521 / dev acc: 0.868 / test acc: 0.864
# train loss: 125.856 / dev loss: 202.644 / test loss: 203.111 / dev acc: 0.865 / test acc: 0.864
# train loss: 128.192 / dev loss: 201.658 / test loss: 205.028 / dev acc: 0.863 / test acc: 0.862
# train loss: 125.133 / dev loss: 191.619 / test loss: 194.385 / dev acc: 0.869 / test acc: 0.869
# train loss: 123.024 / dev loss: 192.117 / test loss: 194.124 / dev acc: 0.868 / test acc: 0.867
# train loss: 131.132 / dev loss: 199.545 / test loss: 201.221 / dev acc: 0.864 / test acc: 0.860
# train loss: 121.438 / dev loss: 193.462 / test loss: 196.857 / dev acc: 0.866 / test acc: 0.866
# train loss: 129.445 / dev loss: 197.187 / test loss: 201.848 / dev acc: 0.865 / test acc: 0.862
# train loss: 130.062 / dev loss: 198.528 / test loss: 200.984 / dev acc: 0.867 / test acc: 0.863
# train loss: 128.143 / dev loss: 197.531 / test loss: 199.123 / dev acc: 0.867 / test acc: 0.866
# train loss: 134.936 / dev loss: 205.705 / test loss: 207.783 / dev acc: 0.860 / test acc: 0.856
# train loss: 127.315 / dev loss: 197.187 / test loss: 195.958 / dev acc: 0.864 / test acc: 0.864
# train loss: 128.696 / dev loss: 201.093 / test loss: 200.208 / dev acc: 0.862 / test acc: 0.864
# train loss: 129.801 / dev loss: 194.588 / test loss: 195.011 / dev acc: 0.867 / test acc: 0.865
# train loss: 127.560 / dev loss: 195.375 / test loss: 192.644 / dev acc: 0.865 / test acc: 0.865
# train loss: 128.461 / dev loss: 195.911 / test loss: 191.717 / dev acc: 0.865 / test acc: 0.869
# train loss: 128.918 / dev loss: 192.285 / test loss: 189.116 / dev acc: 0.864 / test acc: 0.870
# train loss: 131.276 / dev loss: 194.549 / test loss: 192.400 / dev acc: 0.865 / test acc: 0.868
# train loss: 128.869 / dev loss: 196.399 / test loss: 195.613 / dev acc: 0.866 / test acc: 0.868
# train loss: 125.842 / dev loss: 193.701 / test loss: 191.366 / dev acc: 0.866 / test acc: 0.868
# train loss: 129.625 / dev loss: 195.552 / test loss: 189.900 / dev acc: 0.866 / test acc: 0.868
# train loss: 127.349 / dev loss: 197.655 / test loss: 193.617 / dev acc: 0.864 / test acc: 0.868
# train loss: 126.496 / dev loss: 192.595 / test loss: 190.781 / dev acc: 0.866 / test acc: 0.868
# train loss: 133.922 / dev loss: 200.611 / test loss: 198.394 / dev acc: 0.861 / test acc: 0.865
# train loss: 127.709 / dev loss: 195.977 / test loss: 193.103 / dev acc: 0.867 / test acc: 0.869
# train loss: 128.483 / dev loss: 195.996 / test loss: 192.731 / dev acc: 0.865 / test acc: 0.867
# train loss: 128.178 / dev loss: 194.647 / test loss: 191.199 / dev acc: 0.862 / test acc: 0.866
# train loss: 134.920 / dev loss: 194.723 / test loss: 191.473 / dev acc: 0.868 / test acc: 0.869
# train loss: 131.602 / dev loss: 205.678 / test loss: 201.438 / dev acc: 0.863 / test acc: 0.867
# train loss: 128.408 / dev loss: 199.673 / test loss: 193.746 / dev acc: 0.862 / test acc: 0.868
# train loss: 125.789 / dev loss: 200.912 / test loss: 195.777 / dev acc: 0.865 / test acc: 0.868
# train loss: 129.836 / dev loss: 197.496 / test loss: 193.625 / dev acc: 0.864 / test acc: 0.869
# train loss: 124.412 / dev loss: 195.409 / test loss: 191.274 / dev acc: 0.867 / test acc: 0.871
# train loss: 129.081 / dev loss: 204.962 / test loss: 202.201 / dev acc: 0.862 / test acc: 0.863
# train loss: 127.154 / dev loss: 203.311 / test loss: 196.992 / dev acc: 0.863 / test acc: 0.870
# train loss: 136.566 / dev loss: 195.250 / test loss: 194.691 / dev acc: 0.866 / test acc: 0.867
# train loss: 133.240 / dev loss: 195.352 / test loss: 194.335 / dev acc: 0.866 / test acc: 0.868
# train loss: 130.035 / dev loss: 196.018 / test loss: 193.998 / dev acc: 0.867 / test acc: 0.869
# epoch: 10
# train loss: 124.213 / dev loss: 202.185 / test loss: 200.185 / dev acc: 0.865 / test acc: 0.866
# train loss: 119.291 / dev loss: 193.366 / test loss: 191.204 / dev acc: 0.866 / test acc: 0.870
# train loss: 116.475 / dev loss: 194.281 / test loss: 192.671 / dev acc: 0.872 / test acc: 0.872
# train loss: 124.384 / dev loss: 196.708 / test loss: 193.697 / dev acc: 0.869 / test acc: 0.869
# train loss: 120.631 / dev loss: 195.095 / test loss: 192.650 / dev acc: 0.873 / test acc: 0.873
# train loss: 123.968 / dev loss: 194.854 / test loss: 193.168 / dev acc: 0.867 / test acc: 0.867
# train loss: 124.977 / dev loss: 199.975 / test loss: 198.735 / dev acc: 0.865 / test acc: 0.865
# train loss: 120.141 / dev loss: 189.187 / test loss: 190.057 / dev acc: 0.870 / test acc: 0.872
# train loss: 123.722 / dev loss: 199.141 / test loss: 199.628 / dev acc: 0.867 / test acc: 0.867
# train loss: 121.703 / dev loss: 201.488 / test loss: 202.789 / dev acc: 0.863 / test acc: 0.863
# train loss: 125.231 / dev loss: 196.479 / test loss: 200.034 / dev acc: 0.867 / test acc: 0.862
# train loss: 120.315 / dev loss: 208.055 / test loss: 209.851 / dev acc: 0.861 / test acc: 0.861
# train loss: 116.309 / dev loss: 189.385 / test loss: 189.571 / dev acc: 0.871 / test acc: 0.871
# train loss: 123.102 / dev loss: 194.139 / test loss: 192.729 / dev acc: 0.867 / test acc: 0.869
# train loss: 125.427 / dev loss: 197.318 / test loss: 195.463 / dev acc: 0.864 / test acc: 0.869
# train loss: 120.241 / dev loss: 196.620 / test loss: 195.230 / dev acc: 0.865 / test acc: 0.865
# train loss: 122.999 / dev loss: 195.352 / test loss: 196.513 / dev acc: 0.864 / test acc: 0.866
# train loss: 130.459 / dev loss: 194.874 / test loss: 193.758 / dev acc: 0.866 / test acc: 0.868
# train loss: 130.266 / dev loss: 197.135 / test loss: 195.016 / dev acc: 0.866 / test acc: 0.867
# train loss: 123.231 / dev loss: 200.240 / test loss: 200.162 / dev acc: 0.862 / test acc: 0.864
# train loss: 122.549 / dev loss: 202.432 / test loss: 202.875 / dev acc: 0.861 / test acc: 0.861
# train loss: 124.578 / dev loss: 196.667 / test loss: 196.380 / dev acc: 0.864 / test acc: 0.866
# train loss: 131.823 / dev loss: 198.291 / test loss: 194.904 / dev acc: 0.863 / test acc: 0.865
# train loss: 128.264 / dev loss: 198.291 / test loss: 194.833 / dev acc: 0.866 / test acc: 0.866
# train loss: 128.093 / dev loss: 215.002 / test loss: 212.168 / dev acc: 0.852 / test acc: 0.854
# train loss: 121.511 / dev loss: 194.110 / test loss: 190.425 / dev acc: 0.864 / test acc: 0.871
# train loss: 125.746 / dev loss: 195.577 / test loss: 194.465 / dev acc: 0.862 / test acc: 0.865
# train loss: 124.161 / dev loss: 202.828 / test loss: 199.142 / dev acc: 0.860 / test acc: 0.863
# train loss: 126.137 / dev loss: 196.727 / test loss: 193.388 / dev acc: 0.864 / test acc: 0.867
# train loss: 124.206 / dev loss: 193.608 / test loss: 191.977 / dev acc: 0.871 / test acc: 0.869
# train loss: 122.445 / dev loss: 195.406 / test loss: 192.972 / dev acc: 0.869 / test acc: 0.869
# train loss: 125.471 / dev loss: 201.231 / test loss: 196.737 / dev acc: 0.866 / test acc: 0.868
# train loss: 122.457 / dev loss: 192.141 / test loss: 187.219 / dev acc: 0.868 / test acc: 0.872
# train loss: 124.791 / dev loss: 199.292 / test loss: 193.694 / dev acc: 0.869 / test acc: 0.871
# train loss: 128.047 / dev loss: 195.138 / test loss: 190.847 / dev acc: 0.867 / test acc: 0.868
# train loss: 129.080 / dev loss: 197.168 / test loss: 191.248 / dev acc: 0.866 / test acc: 0.871
# train loss: 129.792 / dev loss: 195.561 / test loss: 190.020 / dev acc: 0.865 / test acc: 0.870
# train loss: 127.045 / dev loss: 198.114 / test loss: 195.204 / dev acc: 0.869 / test acc: 0.866
# train loss: 132.044 / dev loss: 195.923 / test loss: 191.321 / dev acc: 0.866 / test acc: 0.867
# train loss: 128.714 / dev loss: 196.385 / test loss: 194.033 / dev acc: 0.864 / test acc: 0.867
# train loss: 129.478 / dev loss: 191.110 / test loss: 188.442 / dev acc: 0.868 / test acc: 0.870
# train loss: 131.361 / dev loss: 189.139 / test loss: 186.208 / dev acc: 0.868 / test acc: 0.871
# train loss: 131.192 / dev loss: 199.083 / test loss: 196.297 / dev acc: 0.868 / test acc: 0.866
# train loss: 129.176 / dev loss: 194.135 / test loss: 193.527 / dev acc: 0.869 / test acc: 0.864
# train loss: 129.445 / dev loss: 190.128 / test loss: 189.520 / dev acc: 0.869 / test acc: 0.868
# train loss: 124.966 / dev loss: 206.134 / test loss: 206.125 / dev acc: 0.858 / test acc: 0.857
# train loss: 129.026 / dev loss: 202.755 / test loss: 201.352 / dev acc: 0.865 / test acc: 0.862
# train loss: 129.938 / dev loss: 194.455 / test loss: 193.901 / dev acc: 0.867 / test acc: 0.866
# max dev acc: 0.873 / max test acc: 0.873
# training finished!

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8ff341ac-3922-4a0d-98da-50de0fc05567" name="files[]" multiple disabled />
#      <output id="result-8ff341ac-3922-4a0d-98da-50de0fc05567">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.tsv to test.tsv
# Saving dev.tsv to dev.tsv
